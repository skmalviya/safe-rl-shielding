# %%
import numpy as np
from matplotlib import pyplot as plt
import pandas as pd

UNSHIELDED = 'unshielded_reset'
EXACT = 'exact_reset'
EXACT_SHAPED = 'exact_reset_shaped'

REWARDS_FILE = 'avg_reward.data'
EPLEN_FILE = 'episodelen.data'

# %%
names=['len',]

unshielded = pd.read_csv(UNSHIELDED + '_' + EPLEN_FILE, names=names)
exact = pd.read_csv(EXACT + '_' + EPLEN_FILE, names=names)
shaped = pd.read_csv(EXACT_SHAPED + '_' + EPLEN_FILE, names=names)

# %%
exact[:200].plot()
plt.show()

# %%
unshielded[:200].plot()
plt.show()

# %%
shaped[:200].plot()
plt.show()

# %%
data = unshielded.merge(exact,
                        how='outer',
                        left_index=True,
                        right_index=True,
                        suffixes=('_u', '_s'))
data = data.rename(columns={'len_u': 'unsafe', 'len_s': 'shielded'})
data = data.merge(shaped,
                 how='outer',
                 left_index=True,
                 right_index=True).rename(columns={'len': 'shaped'})
data[:100].plot()
plt.xlabel('episode')
plt.ylabel('episode length')
plt.show()

# %%
data[60:100].plot()
plt.xlabel('episode')
plt.ylabel('episode length')
plt.show()

# %%
data[:100].plot(logy=True)
plt.xlabel('episode')
plt.ylabel('episode length (logscale)')
plt.show()
